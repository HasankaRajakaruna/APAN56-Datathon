# %% [markdown]
# <a href="https://colab.research.google.com/github/HasankaRajakaruna/APAN56-Datathon/blob/main/churn_sorter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import files

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-34b3e22a-ff3a-4b4e-9419-16445573e3d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34b3e22a-ff3a-4b4e-9419-16445573e3d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
train_churn_list = pd.read_csv('/content/filtered_source_data.csv')
train_churn_list.head()
# Out:
#                                          customer_id  day_no  \
# 0  9e2adb8e95b6d4f0d645ad02c8cbd935ec7701ec5da225...       1
# 1  9e2adb8e95b6d4f0d645ad02c8cbd935ec7701ec5da225...       2
# 2  9e2adb8e95b6d4f0d645ad02c8cbd935ec7701ec5da225...       3
# 3  9e2adb8e95b6d4f0d645ad02c8cbd935ec7701ec5da225...       4
# 4  9e2adb8e95b6d4f0d645ad02c8cbd935ec7701ec5da225...       5
#
#    usage_app_facebook_daily  usage_app_helakuru_daily  usage_app_other  \
# 0                     82.51                     10.08            89.54
# 1                     67.23                      9.73           108.57
# 2                     80.07                      9.69           103.84
# 3                     76.98                      9.36           103.62
# 4                     62.51                      9.29            41.36
#
#    usage_app_tiktok_daily  usage_app_whatsapp_daily  usage_app_youtube_daily  \
# 0                  100.64                      0.00                   119.08
# ...

# %%
sorted_train_churn_list = train_churn_list.sort_values(by=['customer_id', 'day_no'],ascending=True)

# %%
sorted_train_churn_list.head(250)
# Out:
#                                            customer_id  day_no  \
# 0    9e2adb8e95b6d4f0d645ad02c8cbd935ec7701ec5da225...       1
# 1    9e2adb8e95b6d4f0d645ad02c8cbd935ec7701ec5da225...       2
# 2    9e2adb8e95b6d4f0d645ad02c8cbd935ec7701ec5da225...       3
# 3    9e2adb8e95b6d4f0d645ad02c8cbd935ec7701ec5da225...       4
# 4    9e2adb8e95b6d4f0d645ad02c8cbd935ec7701ec5da225...       5
# ..                                                 ...     ...
# 245  f4972d45b42830d180360f2a2b5e921e5f67aa18ad09e9...      66
# 246  f4972d45b42830d180360f2a2b5e921e5f67aa18ad09e9...      67
# 247  f4972d45b42830d180360f2a2b5e921e5f67aa18ad09e9...      68
# 248  f4972d45b42830d180360f2a2b5e921e5f67aa18ad09e9...      69
# 249  f4972d45b42830d180360f2a2b5e921e5f67aa18ad09e9...      70
#
#      usage_app_facebook_daily  usage_app_helakuru_daily  usage_app_other  \
# 0                       82.51                     10.08            89.54
# ...

# %%
sorted_train_churn_list.to_csv('sorted_filtered_source_data.csv', index=False)
